# %%
import pandas as pd
import os

database_path = "/mnt/L-HDD/try/"

beatmaps_csv = os.path.join(database_path, "beatmaps.csv")
formatted_csv = os.path.join(database_path, "hit-object_formatted.csv")

beatmaps_df = pd.read_csv(beatmaps_csv, parse_dates=["ranked_date"])
formatted_df = pd.read_csv(formatted_csv)

# %%
formatted_df
# Out:
#                 ID   Time     Type    X    Y  HitSound  \
# 0        1509063-0   3580   slider  135   26         0
# 1        1509063-0   4270   slider  385   75         0
# 2        1509063-0   4615   circle  365  204         0
# 3        1509063-0   4787   circle  365  204         0
# 4        1509063-0   5132   circle  414  371         0
# ...            ...    ...      ...  ...  ...       ...
# 5253029  2260460-2  94575   slider    6  214         0
# 5253030  2260460-2  95512   circle  254  122         4
# 5253031  2260460-2  95981   circle  193  260         4
# 5253032  2260460-2  96450   circle   90  214         4
# 5253033  2260460-2  96684  spinner  256  192         2
#
#                                                      Extra  beatmap_id  \
# 0        B|181:10|217:45|225:69|225:69|235:91|271:132|3...     1509063
# 1                                        P|349:124|353:174     1509063
# 2                                                        0     1509063
# 3                                                        0     1509063
# 4                                                        0     1509063
# ...                                                    ...         ...
# 5253029                              B|21:119|60:174|78:63     2260460
# 5253030                                                  0     2260460
# 5253031                                                  0     2260460
# 5253032                                                  0     2260460
# 5253033                                              98325     2260460
#
#          beat_length  meter  slider_velocity  sample_set  volume  effects
# 0         344.827586    4.0      -142.000000         1.0    60.0      0.0
# 1         344.827586    4.0      -108.695652         3.0    60.0      0.0
# 2         344.827586    4.0      -108.695652         3.0    60.0      0.0
# 3         344.827586    4.0      -108.695652         3.0    60.0      0.0
# 4         344.827586    4.0      -108.695652         3.0    60.0      0.0
# ...              ...    ...              ...         ...     ...      ...
# 5253029   937.500000    4.0       -83.333333         2.0    85.0      1.0
# 5253030   937.500000    4.0       -83.333333         2.0    85.0      1.0
# 5253031   937.500000    4.0       -83.333333         2.0    85.0      1.0
# 5253032   937.500000    4.0      -100.000000         2.0    70.0      0.0
# 5253033   937.500000    4.0      -100.000000         2.0    70.0      0.0
#
# [5253034 rows x 14 columns]
