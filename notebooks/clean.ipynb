# %%
import pandas as pd

# %%
beatmaps_df = pd.read_csv("/mnt/L-HDD/dataset/beatmaps.csv")

# %%
beatmaps_df
# Out:
#               id                         title          artist   creator  \
# 0      1509063-0      Break Away (feat. RIENK)      Andromedik  Flowziee
# 1      1509063-1      Break Away (feat. RIENK)      Andromedik  Flowziee
# 2      1509063-2      Break Away (feat. RIENK)      Andromedik  Flowziee
# 3      1509063-3      Break Away (feat. RIENK)      Andromedik  Flowziee
# 4       614286-1                   ending note  Yousei Teikoku     Saten
# ...          ...                           ...             ...       ...
# 11597  2130536-0  TRUST IN ETERNITY (Cut Ver.)    Inori Minase     espii
# 11598  2130536-1  TRUST IN ETERNITY (Cut Ver.)    Inori Minase     espii
# 11599  2130536-2  TRUST IN ETERNITY (Cut Ver.)    Inori Minase     espii
# 11600  2130536-3  TRUST IN ETERNITY (Cut Ver.)    Inori Minase     espii
# 11601  2130536-4  TRUST IN ETERNITY (Cut Ver.)    Inori Minase     espii
#
#                 version hp_drain_rate circle_size  overall_difficulty  \
# ...

# %%
beatmaps_df[~beatmaps_df["Unnamed: 17"].isna()]
# Out:
#              id                    title   artist creator version  \
# 2000  1714509-0  Effluxion feat. Ririsya  Zenpaku  Kujinn     NaN
# 2003  1714509-3  Effluxion feat. Ririsya  Zenpaku  Kujinn     NaN
#
#      hp_drain_rate                    circle_size  overall_difficulty  \
# 2000           NaN       Peace<-?->==Void Influx-                 6.0
# 2003           NaN  Master<-?->==Nymphe x Kujinn-                 5.5
#
#       approach_rate  slider_multiplier  slider_tick_rate break_points status  \
# 2000            4.3                9.0               9.8         2.04      1
# 2003            4.2                8.6               9.4         2.54      1
#
#             ranked_date difficulty_rating                 beatmap_id  \
# 2000  ['2,51998,60100']            ranked  2022-03-15 06:04:32+00:00
# 2003  ['2,51998,60070']            ranked  2022-03-15 06:04:32+00:00
#
#       Unnamed: 16  Unnamed: 17
# 2000         7.42    1714509.0
# 2003         6.65    1714509.0

# %%
beatmaps_df = beatmaps_df[~beatmaps_df["id"].isin(["1714509-0", "1714509-3", "2132486-0"])]

# %%
beatmaps_df.drop(columns = ["Unnamed: 16", "Unnamed: 17"], inplace=True)
# Out:
# /tmp/ipykernel_11411/3114422004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beatmaps_df.drop(columns = ["Unnamed: 16", "Unnamed: 17"], inplace=True)

# %%
beatmaps_df.to_csv("/mnt/L-HDD/dataset/cleaned_beatmaps.csv", index=False)

# %%
dataset_df = pd.read_csv("/mnt/L-HDD/dataset/dataset.csv")

# %%
dataset_df = dataset_df[~dataset_df["id"].isin(["1714509-0", "1714509-3", "2132486-0"])]

# %%
dataset_df.to_csv("/mnt/L-HDD/dataset/cleaned_dataset.csv", index=False)
