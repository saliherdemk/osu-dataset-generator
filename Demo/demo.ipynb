# %%
import zipfile
def extract_osz(osz_file, output_folder):
    with zipfile.ZipFile(osz_file, 'r') as zip_ref:
        zip_ref.extractall(output_folder)
    print(f"Extracted {osz_file} to {output_folder}")

# %%
extract_osz("example/Favorite Liar.osz", "example/beatmapset-2269930")
# Out:
# Extracted example/Favorite Liar.osz to example/beatmapset-2269930

# %%
import os

class BeatmapProcessor:
    def __init__(self, beatmapset_folder, osu_file):
        self.beatmapset_folder = beatmapset_folder
        self.osu_file = osu_file
        self.hit_objects = self.parse_hit_objects()
        self.timing_points = self.parse_timing_points()
        self.metadata = self.parse_metadata()
        self.difficulty = self.parse_difficulty()

    def parse_hit_objects(self):
        hit_objects = []
        with open(
            os.path.join(self.beatmapset_folder, self.osu_file), "r", encoding="utf-8"
        ) as f:
            lines = f.readlines()

        in_hit_objects = False
        for line in lines:
            line = line.strip()
            if line == "[HitObjects]":
                in_hit_objects = True
                continue

            if in_hit_objects and line:
                parts = line.split(",")
                x, y, time, obj_type, hit_sound = map(int, parts[:5])
                object_data = parts[5:]

                if obj_type & 1:
                    hit_objects.append(
                        {
                            "type": "circle",
                            "x": x,
                            "y": y,
                            "time": time,
                            "hit_sound": hit_sound,
                        }
                    )

                elif obj_type & 2:
                    slider_path = object_data[0]
                    repeat = int(object_data[1])
                    hit_objects.append(
                        {
                            "type": "slider",
                            "x": x,
                            "y": y,
                            "time": time,
                            "hit_sound": hit_sound,
                            "path": slider_path,
                            "repeat": repeat,
                        }
                    )

                elif obj_type & 8:
                    end_time = int(object_data[0])
                    hit_objects.append(
                        {
                            "type": "spinner",
                            "x": x,
                            "y": y,
                            "time": time,
                            "hit_sound": hit_sound,
                            "end_time": end_time,
                        }
                    )

        return hit_objects

    def parse_timing_points(self):
        timing_points = []
        with open(
            os.path.join(self.beatmapset_folder, self.osu_file), "r", encoding="utf-8"
        ) as f:
            lines = f.readlines()

        in_timing_points = False
        for line in lines:
            line = line.strip()
            if line.startswith("["):
                in_timing_points = line == "[TimingPoints]"
                continue
            if in_timing_points and line:
                parts = line.split(",")

                while len(parts) < 8:
                    parts.append("")

                timing_points.append(
                    {
                        "offset": parts[0],
                        "ms_per_beat": parts[1],
                        "time_signature": parts[2],
                        "meter": parts[3],
                        "sample_set": parts[4],
                        "sample_index": parts[5],
                        "volume": parts[6],
                        "effects": parts[7],
                    }
                )

        return timing_points

    def parse_metadata(self):
        metadata = {}
        with open(
            os.path.join(self.beatmapset_folder, self.osu_file), "r", encoding="utf-8"
        ) as f:
            lines = f.readlines()

        in_metadata = False
        for line in lines:
            line = line.strip()
            if line.startswith("["):
                in_metadata = line == "[Metadata]"
                continue
            if in_metadata and line:
                key, value = line.split(":", 1)
                metadata[key.strip()] = value.strip()

        return metadata

    def parse_difficulty(self):
        difficulty = {}
        with open(
            os.path.join(self.beatmapset_folder, self.osu_file), "r", encoding="utf-8"
        ) as f:
            lines = f.readlines()

        in_difficulty = False
        for line in lines:
            line = line.strip()
            if line.startswith("["):
                in_difficulty = line == "[Difficulty]"
                continue
            if in_difficulty and line:
                key, value = line.split(":", 1)
                difficulty[key.strip()] = value.strip()

        return difficulty

    def get_data(self):
        return {
            "hit_objects": self.hit_objects,
            "timing_points": self.timing_points,
            "metadata": self.metadata,
            "difficulty": self.difficulty,
        }

# %%
import time
import pygame

DEFAULT_SOUNDS = {
        "drum-hitclap", "drum-hitfinish", "drum-hitnormal", "drum-hitwhistle", "drum-sliderslide", "drum-slidertick", "drum-sliderwhistle",
        "normal-hitclap", "normal-hitfinish", "normal-hitnormal", "normal-hitwhistle", "normal-sliderslide", "normal-slidertick", "normal-sliderwhistle",
        "soft-hitclap", "soft-hitfinish", "soft-hitnormal", "soft-hitwhistle", "soft-sliderslide", "soft-slidertick", "soft-sliderwhistle",
        "spinnerbonus", "spinnerspin"
}

class BeatmapPlayer:
    def __init__(self):
        pass

    def list_audio_files(self, beatmapset_folder):
        files = [f for f in os.listdir(beatmapset_folder) if f.endswith('.wav')]
        return {file: self.convert_to_default_sound(file) for file in files}

    def match_hit_objects_to_sounds(self, hit_objects, audios):

        def decode_hit_sound(hit_sound):
            sounds = []
            if hit_sound & 2:
                sounds.append("whistle")
            if hit_sound & 4:
                sounds.append("finish")
            if hit_sound & 8:
                sounds.append("clap")
            return sounds if sounds else ["normal"]

        for obj in hit_objects:
            sound_names = decode_hit_sound(obj["hit_sound"])
            matched_files = [
                audios[file] for file in audios
                if any(s in file.lower() for s in sound_names)
            ]
            obj["hit_sounds"] = sound_names
            obj["files"] = matched_files

    
    def convert_to_default_sound(self, sound_file):
        filename = os.path.basename(sound_file).lower().replace(".wav", "")
    
        if filename in DEFAULT_SOUNDS:
            return filename
    
        if "soft" in filename:
            prefix = "soft"
        elif "drum" in filename:
            prefix = "drum"
        else:
            prefix = "normal"
    
        if "whistle" in filename:
            hit_type = "hitwhistle"
        elif "finish" in filename:
            hit_type = "hitfinish"
        elif "clap" in filename:
            hit_type = "hitclap"
        elif "sliderslide" in filename:
            hit_type = "sliderslide"
        elif "slidertick" in filename:
            hit_type = "slidertick"
        elif "sliderwhistle" in filename:
            hit_type = "sliderwhistle"
        elif "spinnerbonus" in filename:
            return "spinnerbonus"
        elif "spinnerspin" in filename:
            return "spinnerspin"
        else:
            hit_type = "hitnormal"
    
        return f"{prefix}-{hit_type}"

    def play(self, beatmap):

            beatmapset_folder = beatmap.beatmapset_folder
            hit_objects = beatmap.hit_objects
            audios = self.list_audio_files(beatmapset_folder)
        
            self.match_hit_objects_to_sounds(hit_objects, audios)

            mp3_files = [f for f in os.listdir(beatmapset_folder) if f.endswith('.mp3')]

            if not mp3_files:
                print("No .mp3 file found in the directory.")
                return None
        
            mp3_path = os.path.join(beatmapset_folder, mp3_files[0])
    
            pygame.mixer.init()
            pygame.mixer.music.load(mp3_path)
            pygame.mixer.music.play()
    
            sound_cache = {
                file: pygame.mixer.Sound(os.path.join("default_hitsounds", file + ".wav"))
                for file in audios.values()
            }
    
            start_time = time.time()
    
            for obj in hit_objects:
                while (time.time() - start_time) * 1000 < obj["time"]:
                    time.sleep(0.001)
    
                for sound_file in obj["files"]:
                    if sound_file in sound_cache:
                        sound_cache[sound_file].play()
    
                print(f"Played sound for {obj['type']} at {obj['time']} ms")
    
            while pygame.mixer.music.get_busy():
                time.sleep(0.1)
    
            print("Simulation finished!")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
beatmapset_folder = "example/beatmapset-2269930"
osu_file = "The Wrecks - Favorite Liar (Cut Ver.) (PikAqours) [Amats' Insane].osu"

processor = BeatmapProcessor(beatmapset_folder, osu_file)

processor.get_data()
# Out:
# {'hit_objects': [{'type': 'slider',
#    'x': 96,
#    'y': 132,
#    'time': 8262,
#    'hit_sound': 0,
#    'path': 'P|149:123|203:116',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 282,
#    'y': 97,
#    'time': 8643,
#    'hit_sound': 0,
#    'path': 'P|302:146|288:197',
#    'repeat': 1},
#   {'type': 'circle', 'x': 212, 'y': 230, 'time': 9021, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 285,
#    'y': 343,
#    'time': 9273,
#    'hit_sound': 0,
#    'path': 'P|338:334|392:327',
#    'repeat': 1},
#   {'type': 'circle', 'x': 475, 'y': 350, 'time': 9655, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 475,
#    'y': 350,
#    'time': 9783,
#    'hit_sound': 0,
#    'path': 'P|466:296|459:242',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 332,
#    'y': 132,
#    'time': 10274,
#    'hit_sound': 0,
#    'path': 'P|340:185|347:239',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 284,
#    'y': 291,
#    'time': 10638,
#    'hit_sound': 0,
#    'path': 'P|234:311|183:298',
#    'repeat': 1},
#   {'type': 'circle', 'x': 127, 'y': 237, 'time': 11002, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 2,
#    'y': 269,
#    'time': 11259,
#    'hit_sound': 0,
#    'path': 'P|10:322|17:376',
#    'repeat': 2},
#   {'type': 'slider',
#    'x': 95,
#    'y': 142,
#    'time': 12289,
#    'hit_sound': 0,
#    'path': 'P|148:135|202:126',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 250,
#    'y': 198,
#    'time': 12650,
#    'hit_sound': 0,
#    'path': 'P|303:189|357:182',
#    'repeat': 1},
#   {'type': 'circle', 'x': 419, 'y': 130, 'time': 13011, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 260,
#    'y': 42,
#    'time': 13252,
#    'hit_sound': 0,
#    'path': 'P|209:24|159:41',
#    'repeat': 1},
#   {'type': 'circle', 'x': 86, 'y': 74, 'time': 13646, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 86,
#    'y': 74,
#    'time': 13778,
#    'hit_sound': 0,
#    'path': 'P|94:127|101:181',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 30,
#    'y': 336,
#    'time': 14280,
#    'hit_sound': 0,
#    'path': 'P|83:327|137:320',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 207,
#    'y': 361,
#    'time': 14645,
#    'hit_sound': 0,
#    'path': 'P|260:352|314:345',
#    'repeat': 1},
#   {'type': 'circle', 'x': 381, 'y': 301, 'time': 15011, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 303,
#    'y': 191,
#    'time': 15255,
#    'hit_sound': 0,
#    'path': 'P|294:137|287:83',
#    'repeat': 2},
#   {'type': 'slider',
#    'x': 204,
#    'y': 260,
#    'time': 16024,
#    'hit_sound': 0,
#    'path': 'P|177:255|150:251',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 68,
#    'y': 263,
#    'time': 16280,
#    'hit_sound': 0,
#    'path': 'P|46:214|59:162',
#    'repeat': 1},
#   {'type': 'circle', 'x': 113, 'y': 99, 'time': 16650, 'hit_sound': 2},
#   {'type': 'circle', 'x': 244, 'y': 139, 'time': 16897, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 244,
#    'y': 139,
#    'time': 17020,
#    'hit_sound': 0,
#    'path': 'P|270:134|297:130',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 380,
#    'y': 151,
#    'time': 17267,
#    'hit_sound': 0,
#    'path': 'P|401:102|388:50',
#    'repeat': 2},
#   {'type': 'circle', 'x': 284, 'y': 217, 'time': 18023, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 158,
#    'y': 123,
#    'time': 18275,
#    'hit_sound': 0,
#    'path': 'P|104:131|50:138',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 0,
#    'y': 204,
#    'time': 18645,
#    'hit_sound': 0,
#    'path': 'P|8:257|15:311',
#    'repeat': 1},
#   {'type': 'circle', 'x': 79, 'y': 363, 'time': 19015, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 239,
#    'y': 324,
#    'time': 19262,
#    'hit_sound': 0,
#    'path': 'P|260:275|247:223',
#    'repeat': 1},
#   {'type': 'circle', 'x': 204, 'y': 147, 'time': 19633, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 204,
#    'y': 147,
#    'time': 19756,
#    'hit_sound': 0,
#    'path': 'P|150:155|96:162',
#    'repeat': 1},
#   {'type': 'circle', 'x': 28, 'y': 211, 'time': 20126, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 0,
#    'y': 133,
#    'time': 20250,
#    'hit_sound': 0,
#    'path': 'P|6:79|15:25',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 103,
#    'y': 17,
#    'time': 20641,
#    'hit_sound': 0,
#    'path': 'P|94:70|87:124',
#    'repeat': 1},
#   {'type': 'circle', 'x': 115, 'y': 201, 'time': 21014, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 237,
#    'y': 126,
#    'time': 21263,
#    'hit_sound': 0,
#    'path': 'P|285:104|337:117',
#    'repeat': 1},
#   {'type': 'circle', 'x': 409, 'y': 162, 'time': 21661, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 409,
#    'y': 162,
#    'time': 21793,
#    'hit_sound': 0,
#    'path': 'P|400:215|393:269',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 268,
#    'y': 348,
#    'time': 22280,
#    'hit_sound': 0,
#    'path': 'P|214:339|160:332',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 84,
#    'y': 351,
#    'time': 22640,
#    'hit_sound': 0,
#    'path': 'P|62:302|75:250',
#    'repeat': 1},
#   {'type': 'circle', 'x': 137, 'y': 193, 'time': 23000, 'hit_sound': 2},
#   {'type': 'circle', 'x': 339, 'y': 256, 'time': 23240, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 339,
#    'y': 256,
#    'time': 24265,
#    'hit_sound': 0,
#    'path': 'P|365:201|351:141',
#    'repeat': 1},
#   {'type': 'circle', 'x': 296, 'y': 79, 'time': 24640, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 296,
#    'y': 79,
#    'time': 24765,
#    'hit_sound': 0,
#    'path': 'P|265:84|234:88',
#    'repeat': 1},
#   {'type': 'circle', 'x': 162, 'y': 47, 'time': 25015, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 19,
#    'y': 139,
#    'time': 25265,
#    'hit_sound': 0,
#    'path': 'P|29:200|37:261',
#    'repeat': 1},
#   {'type': 'circle', 'x': 75, 'y': 336, 'time': 25640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 157,
#    'y': 301,
#    'time': 25765,
#    'hit_sound': 0,
#    'path': 'P|146:239|138:178',
#    'repeat': 1},
#   {'type': 'circle', 'x': 191, 'y': 115, 'time': 26140, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 279,
#    'y': 184,
#    'time': 26265,
#    'hit_sound': 0,
#    'path': 'P|337:202|393:180',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 482,
#    'y': 163,
#    'time': 26640,
#    'hit_sound': 0,
#    'path': 'P|471:224|463:285',
#    'repeat': 1},
#   {'type': 'circle', 'x': 403, 'y': 342, 'time': 27015, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 260,
#    'y': 287,
#    'time': 27265,
#    'hit_sound': 0,
#    'path': 'P|229:292|198:296',
#    'repeat': 1},
#   {'type': 'circle', 'x': 155, 'y': 362, 'time': 27515, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 155,
#    'y': 362,
#    'time': 27640,
#    'hit_sound': 0,
#    'path': 'P|93:351|32:343',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 0,
#    'y': 267,
#    'time': 28015,
#    'hit_sound': 0,
#    'path': 'P|5:236|9:205',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 82,
#    'y': 130,
#    'time': 28265,
#    'hit_sound': 0,
#    'path': 'P|138:107|196:125',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 243,
#    'y': 196,
#    'time': 28640,
#    'hit_sound': 0,
#    'path': 'P|304:185|365:177',
#    'repeat': 1},
#   {'type': 'circle', 'x': 434, 'y': 227, 'time': 29015, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 511,
#    'y': 72,
#    'time': 29265,
#    'hit_sound': 0,
#    'path': 'P|449:82|388:90',
#    'repeat': 1},
#   {'type': 'circle', 'x': 323, 'y': 35, 'time': 29640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 323,
#    'y': 35,
#    'time': 29765,
#    'hit_sound': 0,
#    'path': 'P|292:40|261:44',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 141,
#    'y': 22,
#    'time': 30015,
#    'hit_sound': 0,
#    'path': 'P|146:52|150:83',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 220,
#    'y': 125,
#    'time': 30265,
#    'hit_sound': 0,
#    'path': 'P|209:186|201:247',
#    'repeat': 1},
#   {'type': 'circle', 'x': 145, 'y': 307, 'time': 30640, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 145,
#    'y': 307,
#    'time': 30765,
#    'hit_sound': 0,
#    'path': 'P|88:329|30:311',
#    'repeat': 1},
#   {'type': 'circle', 'x': 87, 'y': 198, 'time': 31265, 'hit_sound': 2},
#   {'type': 'circle', 'x': 87, 'y': 198, 'time': 31515, 'hit_sound': 0},
#   {'type': 'circle', 'x': 172, 'y': 107, 'time': 31765, 'hit_sound': 2},
#   {'type': 'circle', 'x': 172, 'y': 107, 'time': 32015, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 263,
#    'y': 241,
#    'time': 32265,
#    'hit_sound': 0,
#    'path': 'B|343:229|302:191|403:175',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 467,
#    'y': 264,
#    'time': 32640,
#    'hit_sound': 0,
#    'path': 'P|432:268|397:273',
#    'repeat': 1},
#   {'type': 'circle', 'x': 330, 'y': 327, 'time': 32890, 'hit_sound': 0},
#   {'type': 'circle', 'x': 263, 'y': 241, 'time': 33015, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 131,
#    'y': 346,
#    'time': 33265,
#    'hit_sound': 0,
#    'path': 'P|125:311|121:276',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 44,
#    'y': 349,
#    'time': 33515,
#    'hit_sound': 0,
#    'path': 'P|38:314|34:279',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 62,
#    'y': 135,
#    'time': 33765,
#    'hit_sound': 0,
#    'path': 'P|67:169|71:204',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 149,
#    'y': 132,
#    'time': 34015,
#    'hit_sound': 0,
#    'path': 'P|154:166|158:201',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 288,
#    'y': 274,
#    'time': 34265,
#    'hit_sound': 0,
#    'path': 'P|321:242|426:255',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 489,
#    'y': 147,
#    'time': 34640,
#    'hit_sound': 0,
#    'path': 'P|454:151|419:156',
#    'repeat': 1},
#   {'type': 'circle', 'x': 357, 'y': 95, 'time': 34890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 279,
#    'y': 147,
#    'time': 35015,
#    'hit_sound': 0,
#    'path': 'P|274:112|270:78',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 145,
#    'y': 34,
#    'time': 35265,
#    'hit_sound': 0,
#    'path': 'P|149:68|154:103',
#    'repeat': 1},
#   {'type': 'circle', 'x': 77, 'y': 136, 'time': 35515, 'hit_sound': 10},
#   {'type': 'circle', 'x': 77, 'y': 136, 'time': 35640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 144,
#    'y': 223,
#    'time': 35765,
#    'hit_sound': 0,
#    'path': 'P|178:218|213:213',
#    'repeat': 1},
#   {'type': 'circle', 'x': 279, 'y': 147, 'time': 36015, 'hit_sound': 10},
#   {'type': 'circle', 'x': 333, 'y': 226, 'time': 36140, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 450,
#    'y': 197,
#    'time': 36265,
#    'hit_sound': 0,
#    'path': 'P|482:256|460:321',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 393,
#    'y': 369,
#    'time': 36640,
#    'hit_sound': 0,
#    'path': 'P|358:364|323:358',
#    'repeat': 1},
#   {'type': 'circle', 'x': 235, 'y': 298, 'time': 36890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 160,
#    'y': 369,
#    'time': 37015,
#    'hit_sound': 0,
#    'path': 'P|155:334|149:299',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 4,
#    'y': 197,
#    'time': 37265,
#    'hit_sound': 0,
#    'path': 'B|22:211|39:230|39:230|100:240|126:178',
#    'repeat': 1},
#   {'type': 'circle', 'x': 157, 'y': 124, 'time': 37640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 281,
#    'y': 168,
#    'time': 37765,
#    'hit_sound': 0,
#    'path': 'B|293:88|331:129|347:28',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 124,
#    'y': 17,
#    'time': 38265,
#    'hit_sound': 0,
#    'path': 'B|24:30|24:30|48:43|66:60',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 157,
#    'y': 124,
#    'time': 38640,
#    'hit_sound': 0,
#    'path': 'P|151:158|146:193',
#    'repeat': 1},
#   {'type': 'circle', 'x': 84, 'y': 241, 'time': 38890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 0,
#    'y': 230,
#    'time': 39015,
#    'hit_sound': 0,
#    'path': 'P|5:264|10:299',
#    'repeat': 1},
#   {'type': 'circle', 'x': 155, 'y': 357, 'time': 39265, 'hit_sound': 10},
#   {'type': 'circle', 'x': 155, 'y': 357, 'time': 39390, 'hit_sound': 8},
#   {'type': 'slider',
#    'x': 266,
#    'y': 263,
#    'time': 39515,
#    'hit_sound': 0,
#    'path': 'P|231:267|196:273',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 344,
#    'y': 329,
#    'time': 39765,
#    'hit_sound': 0,
#    'path': 'P|378:323|413:318',
#    'repeat': 1},
#   {'type': 'circle', 'x': 481, 'y': 252, 'time': 40015, 'hit_sound': 4},
#   {'type': 'circle', 'x': 481, 'y': 252, 'time': 40140, 'hit_sound': 4},
#   {'type': 'circle', 'x': 376, 'y': 157, 'time': 40265, 'hit_sound': 4},
#   {'type': 'spinner',
#    'x': 256,
#    'y': 192,
#    'time': 40327,
#    'hit_sound': 0,
#    'end_time': 43765},
#   {'type': 'slider',
#    'x': 227,
#    'y': 159,
#    'time': 44265,
#    'hit_sound': 0,
#    'path': 'P|232:120|238:82',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 139,
#    'y': 43,
#    'time': 44515,
#    'hit_sound': 0,
#    'path': 'P|133:81|127:119',
#    'repeat': 1},
#   {'type': 'circle', 'x': 30, 'y': 168, 'time': 44765, 'hit_sound': 2},
#   {'type': 'circle', 'x': 30, 'y': 168, 'time': 44890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 64,
#    'y': 261,
#    'time': 45015,
#    'hit_sound': 0,
#    'path': 'P|102:255|140:249',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 227,
#    'y': 159,
#    'time': 45265,
#    'hit_sound': 0,
#    'path': 'P|285:205|359:190',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 470,
#    'y': 144,
#    'time': 45640,
#    'hit_sound': 0,
#    'path': 'P|464:182|458:220',
#    'repeat': 1},
#   {'type': 'circle', 'x': 389, 'y': 279, 'time': 45890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 308,
#    'y': 368,
#    'time': 46015,
#    'hit_sound': 0,
#    'path': 'P|302:329|296:291',
#    'repeat': 1},
#   {'type': 'circle', 'x': 227, 'y': 159, 'time': 46265, 'hit_sound': 2},
#   {'type': 'circle', 'x': 227, 'y': 159, 'time': 46390, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 152,
#    'y': 220,
#    'time': 46515,
#    'hit_sound': 0,
#    'path': 'P|113:225|75:231',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 0,
#    'y': 118,
#    'time': 46765,
#    'hit_sound': 0,
#    'path': 'P|38:112|76:106',
#    'repeat': 1},
#   {'type': 'circle', 'x': 138, 'y': 45, 'time': 47015, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 227,
#    'y': 159,
#    'time': 47140,
#    'hit_sound': 0,
#    'path': 'B|310:154|284:104|393:101',
#    'repeat': 1},
#   {'type': 'circle', 'x': 512, 'y': 156, 'time': 47515, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 463,
#    'y': 24,
#    'time': 47640,
#    'hit_sound': 0,
#    'path': 'P|457:62|451:100',
#    'repeat': 1},
#   {'type': 'circle', 'x': 368, 'y': 196, 'time': 47890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 368,
#    'y': 196,
#    'time': 48015,
#    'hit_sound': 0,
#    'path': 'P|373:234|379:272',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 227,
#    'y': 159,
#    'time': 48265,
#    'hit_sound': 0,
#    'path': 'B|137:124|137:124|114:146|95:165',
#    'repeat': 1},
#   {'type': 'circle', 'x': 24, 'y': 255, 'time': 48640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 118,
#    'y': 324,
#    'time': 48765,
#    'hit_sound': 0,
#    'path': 'P|133:294|120:242',
#    'repeat': 1},
#   {'type': 'circle', 'x': 95, 'y': 165, 'time': 49015, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 215,
#    'y': 203,
#    'time': 49140,
#    'hit_sound': 0,
#    'path': 'P|304:182|379:167',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 488,
#    'y': 218,
#    'time': 49515,
#    'hit_sound': 0,
#    'path': 'P|493:179|499:141',
#    'repeat': 1},
#   {'type': 'circle', 'x': 405, 'y': 261, 'time': 49765, 'hit_sound': 2},
#   {'type': 'circle', 'x': 405, 'y': 261, 'time': 49890, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 512,
#    'y': 334,
#    'time': 50015,
#    'hit_sound': 0,
#    'path': 'P|473:339|435:345',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 285,
#    'y': 288,
#    'time': 50265,
#    'hit_sound': 0,
#    'path': 'P|238:228|256:156',
#    'repeat': 1},
#   {'type': 'circle', 'x': 382, 'y': 63, 'time': 50640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 313,
#    'y': 8,
#    'time': 50765,
#    'hit_sound': 0,
#    'path': 'P|274:13|236:19',
#    'repeat': 1},
#   {'type': 'circle', 'x': 78, 'y': 103, 'time': 51015, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 145,
#    'y': 162,
#    'time': 51140,
#    'hit_sound': 0,
#    'path': 'B|190:139|180:79|180:79|158:62|142:34',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 2,
#    'y': 148,
#    'time': 51515,
#    'hit_sound': 0,
#    'path': 'P|7:186|13:224',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 108,
#    'y': 265,
#    'time': 51765,
#    'hit_sound': 0,
#    'path': 'P|102:303|96:341',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 219,
#    'y': 136,
#    'time': 52015,
#    'hit_sound': 0,
#    'path': 'P|224:174|230:212',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 435,
#    'y': 320,
#    'time': 52265,
#    'hit_sound': 0,
#    'path': 'P|375:273|303:291',
#    'repeat': 1},
#   {'type': 'circle', 'x': 228, 'y': 355, 'time': 52640, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 108,
#    'y': 265,
#    'time': 52765,
#    'hit_sound': 0,
#    'path': 'P|69:270|31:276',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 189,
#    'y': 182,
#    'time': 53015,
#    'hit_sound': 0,
#    'path': 'P|150:176|112:170',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 303,
#    'y': 291,
#    'time': 53265,
#    'hit_sound': 0,
#    'path': 'B|385:277|354:231|462:215',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 299,
#    'y': 184,
#    'time': 53640,
#    'hit_sound': 0,
#    'path': 'P|293:145|287:107',
#    'repeat': 1},
#   {'type': 'circle', 'x': 353, 'y': 45, 'time': 53890, 'hit_sound': 2},
#   {'type': 'circle', 'x': 465, 'y': 132, 'time': 54015, 'hit_sound': 10},
#   {'type': 'circle', 'x': 465, 'y': 132, 'time': 54140, 'hit_sound': 0},
#   {'type': 'circle', 'x': 271, 'y': 81, 'time': 54265, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 271,
#    'y': 81,
#    'time': 56262,
#    'hit_sound': 0,
#    'path': 'B|244:58|228:38|228:38|155:21|124:97',
#    'repeat': 1},
#   {'type': 'circle', 'x': 56, 'y': 162, 'time': 56637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 189,
#    'y': 225,
#    'time': 56762,
#    'hit_sound': 0,
#    'path': 'P|204:185|198:143',
#    'repeat': 1},
#   {'type': 'circle', 'x': 91, 'y': 267, 'time': 57012, 'hit_sound': 10},
#   {'type': 'circle', 'x': 91, 'y': 267, 'time': 57137, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 273,
#    'y': 337,
#    'time': 57262,
#    'hit_sound': 0,
#    'path': 'B|370:326|314:266|431:252',
#    'repeat': 1},
#   {'type': 'circle', 'x': 329, 'y': 191, 'time': 57637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 499,
#    'y': 285,
#    'time': 57762,
#    'hit_sound': 0,
#    'path': 'P|515:211|493:119',
#    'repeat': 1},
#   {'type': 'circle', 'x': 433, 'y': 45, 'time': 58137, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 329,
#    'y': 191,
#    'time': 58262,
#    'hit_sound': 0,
#    'path': 'B|231:180|287:120|170:106',
#    'repeat': 1},
#   {'type': 'circle', 'x': 54, 'y': 172, 'time': 58637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 131,
#    'y': 272,
#    'time': 58762,
#    'hit_sound': 0,
#    'path': 'P|137:229|143:187',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 244,
#    'y': 333,
#    'time': 59012,
#    'hit_sound': 0,
#    'path': 'P|237:290|231:248',
#    'repeat': 1},
#   {'type': 'circle', 'x': 334, 'y': 101, 'time': 59262, 'hit_sound': 2},
#   {'type': 'circle', 'x': 416, 'y': 215, 'time': 59387, 'hit_sound': 0},
#   {'type': 'circle', 'x': 254, 'y': 160, 'time': 59512, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 445,
#    'y': 36,
#    'time': 59637,
#    'hit_sound': 0,
#    'path': 'P|438:78|432:120',
#    'repeat': 1},
#   {'type': 'circle', 'x': 312, 'y': 254, 'time': 59887, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 467,
#    'y': 329,
#    'time': 60012,
#    'hit_sound': 0,
#    'path': 'P|424:335|382:341',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 168,
#    'y': 240,
#    'time': 60262,
#    'hit_sound': 0,
#    'path': 'P|123:170|154:94',
#    'repeat': 1},
#   {'type': 'circle', 'x': 243, 'y': 16, 'time': 60637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 358,
#    'y': 119,
#    'time': 60762,
#    'hit_sound': 0,
#    'path': 'P|315:125|273:131',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 69,
#    'y': 81,
#    'time': 61012,
#    'hit_sound': 0,
#    'path': 'P|111:74|153:68',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 0,
#    'y': 213,
#    'time': 61262,
#    'hit_sound': 0,
#    'path': 'P|84:226|168:239',
#    'repeat': 1},
#   {'type': 'circle', 'x': 248, 'y': 152, 'time': 61637, 'hit_sound': 0},
#   {'type': 'circle', 'x': 353, 'y': 236, 'time': 61762, 'hit_sound': 2},
#   {'type': 'circle', 'x': 353, 'y': 236, 'time': 61887, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 268,
#    'y': 361,
#    'time': 62012,
#    'hit_sound': 0,
#    'path': 'P|253:321|259:279',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 431,
#    'y': 171,
#    'time': 62262,
#    'hit_sound': 0,
#    'path': 'P|354:201|285:157',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 153,
#    'y': 76,
#    'time': 62637,
#    'hit_sound': 0,
#    'path': 'P|195:69|237:63',
#    'repeat': 1},
#   {'type': 'circle', 'x': 365, 'y': 85, 'time': 62887, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 468,
#    'y': 0,
#    'time': 63012,
#    'hit_sound': 0,
#    'path': 'P|461:42|455:84',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 353,
#    'y': 236,
#    'time': 63262,
#    'hit_sound': 0,
#    'path': 'B|256:247|312:307|195:321',
#    'repeat': 1},
#   {'type': 'circle', 'x': 111, 'y': 215, 'time': 63637, 'hit_sound': 2},
#   {'type': 'slider',
#    'x': 111,
#    'y': 215,
#    'time': 63762,
#    'hit_sound': 0,
#    'path': 'P|151:200|193:206',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 101,
#    'y': 360,
#    'time': 64012,
#    'hit_sound': 0,
#    'path': 'P|68:332|52:293',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 0,
#    'y': 141,
#    'time': 64262,
#    'hit_sound': 0,
#    'path': 'P|54:101|160:114',
#    'repeat': 1},
#   {'type': 'circle', 'x': 216, 'y': 209, 'time': 64637, 'hit_sound': 0},
#   {'type': 'circle', 'x': 269, 'y': 80, 'time': 64762, 'hit_sound': 2},
#   {'type': 'circle', 'x': 269, 'y': 80, 'time': 64887, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 414,
#    'y': 137,
#    'time': 65012,
#    'hit_sound': 0,
#    'path': 'P|371:143|329:150',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 142,
#    'y': 149,
#    'time': 65262,
#    'hit_sound': 0,
#    'path': 'B|153:247|213:191|227:308',
#    'repeat': 1},
#   {'type': 'circle', 'x': 154, 'y': 360, 'time': 65637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 0,
#    'y': 304,
#    'time': 65762,
#    'hit_sound': 0,
#    'path': 'P|41:297|84:291',
#    'repeat': 1},
#   {'type': 'circle', 'x': 216, 'y': 209, 'time': 66012, 'hit_sound': 10},
#   {'type': 'slider',
#    'x': 326,
#    'y': 328,
#    'time': 66137,
#    'hit_sound': 0,
#    'path': 'B|427:295|427:295|474:338',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 512,
#    'y': 193,
#    'time': 66512,
#    'hit_sound': 0,
#    'path': 'P|469:199|427:206',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 269,
#    'y': 141,
#    'time': 66762,
#    'hit_sound': 0,
#    'path': 'P|254:101|259:59',
#    'repeat': 1},
#   {'type': 'circle', 'x': 348, 'y': 6, 'time': 67012, 'hit_sound': 10},
#   {'type': 'circle', 'x': 469, 'y': 56, 'time': 67137, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 388,
#    'y': 205,
#    'time': 67262,
#    'hit_sound': 0,
#    'path': 'P|381:162|374:120',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 497,
#    'y': 288,
#    'time': 67512,
#    'hit_sound': 0,
#    'path': 'P|503:245|510:203',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 299,
#    'y': 256,
#    'time': 67762,
#    'hit_sound': 0,
#    'path': 'P|306:298|313:340',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 196,
#    'y': 156,
#    'time': 68012,
#    'hit_sound': 0,
#    'path': 'P|190:198|184:241',
#    'repeat': 1},
#   {'type': 'slider',
#    'x': 250,
#    'y': 22,
#    'time': 68262,
#    'hit_sound': 0,
#    'path': 'P|180:68|104:35',
#    'repeat': 1},
#   {'type': 'circle', 'x': 22, 'y': 79, 'time': 68637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 90,
#    'y': 142,
#    'time': 68762,
#    'hit_sound': 0,
#    'path': 'P|83:184|76:226',
#    'repeat': 2},
#   {'type': 'slider',
#    'x': 278,
#    'y': 187,
#    'time': 69262,
#    'hit_sound': 0,
#    'path': 'B|379:154|379:154|426:197',
#    'repeat': 1},
#   {'type': 'circle', 'x': 319, 'y': 303, 'time': 69637, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 187,
#    'y': 239,
#    'time': 69762,
#    'hit_sound': 0,
#    'path': 'P|172:199|177:157',
#    'repeat': 1},
#   {'type': 'circle', 'x': 309, 'y': 75, 'time': 70012, 'hit_sound': 10},
#   {'type': 'circle', 'x': 278, 'y': 187, 'time': 70137, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 101,
#    'y': 102,
#    'time': 70262,
#    'hit_sound': 0,
#    'path': 'P|58:108|16:115',
#    'repeat': 1},
#   {'type': 'circle', 'x': 195, 'y': 30, 'time': 70512, 'hit_sound': 8},
#   {'type': 'circle', 'x': 195, 'y': 30, 'time': 70637, 'hit_sound': 0},
#   {'type': 'circle', 'x': 309, 'y': 75, 'time': 70762, 'hit_sound': 8},
#   {'type': 'circle', 'x': 309, 'y': 75, 'time': 70887, 'hit_sound': 0},
#   {'type': 'slider',
#    'x': 442,
#    'y': 19,
#    'time': 71012,
#    'hit_sound': 0,
#    'path': 'P|434:61|428:103',
#    'repeat': 1},
#   {'type': 'circle', 'x': 296, 'y': 277, 'time': 71262, 'hit_sound': 8},
#   {'type': 'circle', 'x': 347, 'y': 165, 'time': 71387, 'hit_sound': 8},
#   {'type': 'slider',
#    'x': 501,
#    'y': 210,
#    'time': 71512,
#    'hit_sound': 0,
#    'path': 'P|458:217|416:223',
#    'repeat': 1},
#   {'type': 'circle', 'x': 257, 'y': 191, 'time': 71762, 'hit_sound': 8},
#   {'type': 'circle', 'x': 390, 'y': 307, 'time': 71887, 'hit_sound': 8},
#   {'type': 'circle', 'x': 430, 'y': 133, 'time': 72012, 'hit_sound': 8},
#   {'type': 'circle', 'x': 296, 'y': 277, 'time': 72137, 'hit_sound': 8},
#   {'type': 'circle', 'x': 240, 'y': 79, 'time': 72262, 'hit_sound': 6},
#   {'type': 'spinner',
#    'x': 256,
#    'y': 192,
#    'time': 72324,
#    'hit_sound': 2,
#    'end_time': 76262},
#   {'type': 'spinner',
#    'x': 256,
#    'y': 192,
#    'time': 76324,
#    'hit_sound': 0,
#    'end_time': 79762}],
#  'timing_points': [{'offset': '245',
#    'ms_per_beat': '266.666666666667',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '289',
#    'ms_per_beat': '-100',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '645',
#    'ms_per_beat': '247.933884297521',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '1264',
#    'ms_per_beat': '263.157894736842',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '1790',
#    'ms_per_beat': '244.897959183673',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '2279',
#    'ms_per_beat': '241.935483870968',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '3246',
#    'ms_per_beat': '260.869565217391',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '3767',
#    'ms_per_beat': '252.100840336134',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '4271',
#    'ms_per_beat': '245.901639344262',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '5254',
#    'ms_per_beat': '263.157894736842',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '5780',
#    'ms_per_beat': '244.897959183673',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '6269',
#    'ms_per_beat': '244.897959183673',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '7248',
#    'ms_per_beat': '260.869565217391',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '7769',
#    'ms_per_beat': '246.913580246914',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '8262',
#    'ms_per_beat': '254.237288135593',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '8262',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '8643',
#    'ms_per_beat': '252.100840336134',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '8643',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '9273',
#    'ms_per_beat': '255.31914893617',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '9273',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '9783',
#    'ms_per_beat': '245.901639344262',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '9783',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '10274',
#    'ms_per_beat': '242.914979757085',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '10274',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '11002',
#    'ms_per_beat': '257.510729613734',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '11259',
#    'ms_per_beat': '257.510729613734',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '11259',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '12289',
#    'ms_per_beat': '240.963855421687',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '12289',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '13252',
#    'ms_per_beat': '263.157894736842',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '13252',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '13778',
#    'ms_per_beat': '251.046025104603',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '13778',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '14280',
#    'ms_per_beat': '243.90243902439',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '14280',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '15255',
#    'ms_per_beat': '256.410256410256',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '15255',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '16280',
#    'ms_per_beat': '246.913580246914',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '16280',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '17267',
#    'ms_per_beat': '252.100840336134',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '17267',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '18275',
#    'ms_per_beat': '246.913580246914',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '18275',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '20250',
#    'ms_per_beat': '260.869565217391',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '20250',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '20641',
#    'ms_per_beat': '248.96265560166',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '20641',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '21263',
#    'ms_per_beat': '265.486725663717',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '21263',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '21793',
#    'ms_per_beat': '243.90243902439',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '21793',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '22280',
#    'ms_per_beat': '240',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '22280',
#    'ms_per_beat': '-142.857142857143',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '23240',
#    'ms_per_beat': '256.410256410256',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '24265',
#    'ms_per_beat': '250',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '60',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '24265',
#    'ms_per_beat': '-125',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '31390',
#    'ms_per_beat': '-125',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '5',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '31515',
#    'ms_per_beat': '-125',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '31890',
#    'ms_per_beat': '-125',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '5',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '32015',
#    'ms_per_beat': '-125',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '32265',
#    'ms_per_beat': '-111.111111111111',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '80',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '40265',
#    'ms_per_beat': '-111.111111111111',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '44265',
#    'ms_per_beat': '-100',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '90',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '48265',
#    'ms_per_beat': '-100',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '80',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '52431',
#    'ms_per_beat': '-100',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '5',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '52515',
#    'ms_per_beat': '-100',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '80',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '54265',
#    'ms_per_beat': '249.687890137328',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '80',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '54265',
#    'ms_per_beat': '-100',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '56262',
#    'ms_per_beat': '250',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '1',
#    'effects': '0'},
#   {'offset': '56262',
#    'ms_per_beat': '-90.9090909090909',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '100',
#    'volume': '0',
#    'effects': '1'},
#   {'offset': '72262',
#    'ms_per_beat': '-90.9090909090909',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '70',
#    'volume': '0',
#    'effects': '0'},
#   {'offset': '79762',
#    'ms_per_beat': '-90.9090909090909',
#    'time_signature': '4',
#    'meter': '2',
#    'sample_set': '1',
#    'sample_index': '5',
#    'volume': '0',
#    'effects': '0'}],
#  'metadata': {'Title': 'Favorite Liar (Cut Ver.)',
#   'TitleUnicode': 'Favorite Liar (Cut Ver.)',
#   'Artist': 'The Wrecks',
#   'ArtistUnicode': 'The Wrecks',
#   'Creator': 'PikAqours',
#   'Version': "Amats' Insane",
#   'Source': '',
#   'Tags': 'kuroame armada kuki1537 parad0xa harumiii amats fuxi fuxi66 cut short version alt rock punk english favourite male vocalist we are nick anderson',
#   'BeatmapID': '4834691',
#   'BeatmapSetID': '2269930'},
#  'difficulty': {'HPDrainRate': '5',
#   'CircleSize': '3.6',
#   'OverallDifficulty': '8',
#   'ApproachRate': '9',
#   'SliderMultiplier': '1.55',
#   'SliderTickRate': '1'}}

# %%
player = BeatmapPlayer()
player.play(processor)
# Out:
# Played sound for slider at 8262 ms
# Played sound for slider at 8643 ms
# Played sound for circle at 9021 ms
# Played sound for slider at 9273 ms
# Played sound for circle at 9655 ms
# Played sound for slider at 9783 ms
# Played sound for slider at 10274 ms
# Played sound for slider at 10638 ms
# Played sound for circle at 11002 ms
# Played sound for slider at 11259 ms
# Played sound for slider at 12289 ms
# Played sound for slider at 12650 ms
# Played sound for circle at 13011 ms
# Played sound for slider at 13252 ms
# Played sound for circle at 13646 ms
# Played sound for slider at 13778 ms
# Played sound for slider at 14280 ms
# Played sound for slider at 14645 ms
# Played sound for circle at 15011 ms
# Played sound for slider at 15255 ms
# Played sound for slider at 16024 ms
# Played sound for slider at 16280 ms
# Played sound for circle at 16650 ms
# Played sound for circle at 16897 ms
# Played sound for slider at 17020 ms
# Played sound for slider at 17267 ms
# Played sound for circle at 18023 ms
# Played sound for slider at 18275 ms
# Played sound for slider at 18645 ms
# Played sound for circle at 19015 ms
# Played sound for slider at 19262 ms
# Played sound for circle at 19633 ms
# Played sound for slider at 19756 ms
# Played sound for circle at 20126 ms
# Played sound for slider at 20250 ms
# Played sound for slider at 20641 ms
# Played sound for circle at 21014 ms
# Played sound for slider at 21263 ms
# Played sound for circle at 21661 ms
# Played sound for slider at 21793 ms
# Played sound for slider at 22280 ms
# Played sound for slider at 22640 ms
# Played sound for circle at 23000 ms
# Played sound for circle at 23240 ms
# Played sound for slider at 24265 ms
# Played sound for circle at 24640 ms
# Played sound for slider at 24765 ms
# Played sound for circle at 25015 ms
# Played sound for slider at 25265 ms
# Played sound for circle at 25640 ms
# Played sound for slider at 25765 ms
# Played sound for circle at 26140 ms
# Played sound for slider at 26265 ms
# Played sound for slider at 26640 ms
# Played sound for circle at 27015 ms
# Played sound for slider at 27265 ms
# Played sound for circle at 27515 ms
# Played sound for slider at 27640 ms
# Played sound for slider at 28015 ms
# Played sound for slider at 28265 ms
# Played sound for slider at 28640 ms
# Played sound for circle at 29015 ms
# Played sound for slider at 29265 ms
# Played sound for circle at 29640 ms
# Played sound for slider at 29765 ms
# Played sound for slider at 30015 ms
# Played sound for slider at 30265 ms
# Played sound for circle at 30640 ms
# Played sound for slider at 30765 ms
# Played sound for circle at 31265 ms
# Played sound for circle at 31515 ms
# Played sound for circle at 31765 ms
# Played sound for circle at 32015 ms
# Played sound for slider at 32265 ms
# Played sound for slider at 32640 ms
# Played sound for circle at 32890 ms
# Played sound for circle at 33015 ms
# Played sound for slider at 33265 ms
# Played sound for slider at 33515 ms
# Played sound for slider at 33765 ms
# Played sound for slider at 34015 ms
# Played sound for slider at 34265 ms
# Played sound for slider at 34640 ms
# Played sound for circle at 34890 ms
# Played sound for slider at 35015 ms
# Played sound for slider at 35265 ms
# Played sound for circle at 35515 ms
# Played sound for circle at 35640 ms
# Played sound for slider at 35765 ms
# Played sound for circle at 36015 ms
# Played sound for circle at 36140 ms
# Played sound for slider at 36265 ms
# Played sound for slider at 36640 ms
# Played sound for circle at 36890 ms
# Played sound for slider at 37015 ms
# Played sound for slider at 37265 ms
# Played sound for circle at 37640 ms
# Played sound for slider at 37765 ms
# Played sound for slider at 38265 ms
# Played sound for slider at 38640 ms
# Played sound for circle at 38890 ms
# Played sound for slider at 39015 ms
# Played sound for circle at 39265 ms
# Played sound for circle at 39390 ms
# Played sound for slider at 39515 ms
# Played sound for slider at 39765 ms
# Played sound for circle at 40015 ms
# Played sound for circle at 40140 ms
# Played sound for circle at 40265 ms
# Played sound for spinner at 40327 ms
# Played sound for slider at 44265 ms
# Played sound for slider at 44515 ms
# Played sound for circle at 44765 ms
# Played sound for circle at 44890 ms
# Played sound for slider at 45015 ms
# Played sound for slider at 45265 ms
# Played sound for slider at 45640 ms
# Played sound for circle at 45890 ms
# Played sound for slider at 46015 ms
# Played sound for circle at 46265 ms
# Played sound for circle at 46390 ms
# Played sound for slider at 46515 ms
# Played sound for slider at 46765 ms
# Played sound for circle at 47015 ms
# Played sound for slider at 47140 ms
# Played sound for circle at 47515 ms
# Played sound for slider at 47640 ms
# Played sound for circle at 47890 ms
# Played sound for slider at 48015 ms
# Played sound for slider at 48265 ms
# Played sound for circle at 48640 ms
# Played sound for slider at 48765 ms
# Played sound for circle at 49015 ms
# Played sound for slider at 49140 ms
# Played sound for slider at 49515 ms
# Played sound for circle at 49765 ms
# Played sound for circle at 49890 ms
# Played sound for slider at 50015 ms
# Played sound for slider at 50265 ms
# Played sound for circle at 50640 ms
# Played sound for slider at 50765 ms
# Played sound for circle at 51015 ms
# Played sound for slider at 51140 ms
# Played sound for slider at 51515 ms
# Played sound for slider at 51765 ms
# Played sound for slider at 52015 ms
# Played sound for slider at 52265 ms
# Played sound for circle at 52640 ms
# Played sound for slider at 52765 ms
# Played sound for slider at 53015 ms
# Played sound for slider at 53265 ms
# Played sound for slider at 53640 ms
# Played sound for circle at 53890 ms
# Played sound for circle at 54015 ms
# Played sound for circle at 54140 ms
# Played sound for circle at 54265 ms
# Played sound for slider at 56262 ms
# Played sound for circle at 56637 ms
# Played sound for slider at 56762 ms
# Played sound for circle at 57012 ms
# Played sound for circle at 57137 ms
# Played sound for slider at 57262 ms
# Played sound for circle at 57637 ms
# Played sound for slider at 57762 ms
# Played sound for circle at 58137 ms
# Played sound for slider at 58262 ms
# Played sound for circle at 58637 ms
# Played sound for slider at 58762 ms
# Played sound for slider at 59012 ms
# Played sound for circle at 59262 ms
# Played sound for circle at 59387 ms
# Played sound for circle at 59512 ms
# Played sound for slider at 59637 ms
# Played sound for circle at 59887 ms
# Played sound for slider at 60012 ms
# Played sound for slider at 60262 ms
# Played sound for circle at 60637 ms
# Played sound for slider at 60762 ms
# Played sound for slider at 61012 ms
# Played sound for slider at 61262 ms
# Played sound for circle at 61637 ms
# Played sound for circle at 61762 ms
# Played sound for circle at 61887 ms
# Played sound for slider at 62012 ms
# Played sound for slider at 62262 ms
# Played sound for slider at 62637 ms
# Played sound for circle at 62887 ms
# Played sound for slider at 63012 ms
# Played sound for slider at 63262 ms
# Played sound for circle at 63637 ms
# Played sound for slider at 63762 ms
# Played sound for slider at 64012 ms
# Played sound for slider at 64262 ms
# Played sound for circle at 64637 ms
# Played sound for circle at 64762 ms
# Played sound for circle at 64887 ms
# Played sound for slider at 65012 ms
# Played sound for slider at 65262 ms
# Played sound for circle at 65637 ms
# Played sound for slider at 65762 ms
# Played sound for circle at 66012 ms
# Played sound for slider at 66137 ms
# Played sound for slider at 66512 ms
# Played sound for slider at 66762 ms
# Played sound for circle at 67012 ms
# Played sound for circle at 67137 ms
# Played sound for slider at 67262 ms
# Played sound for slider at 67512 ms
# Played sound for slider at 67762 ms
# Played sound for slider at 68012 ms
# Played sound for slider at 68262 ms
# Played sound for circle at 68637 ms
# Played sound for slider at 68762 ms
# Played sound for slider at 69262 ms
# Played sound for circle at 69637 ms
# Played sound for slider at 69762 ms
# Played sound for circle at 70012 ms
# Played sound for circle at 70137 ms
# Played sound for slider at 70262 ms
# Played sound for circle at 70512 ms
# Played sound for circle at 70637 ms
# Played sound for circle at 70762 ms
# Played sound for circle at 70887 ms
# Played sound for slider at 71012 ms
# Played sound for circle at 71262 ms
# Played sound for circle at 71387 ms
# Played sound for slider at 71512 ms
# Played sound for circle at 71762 ms
# Played sound for circle at 71887 ms
# Played sound for circle at 72012 ms
# Played sound for circle at 72137 ms
# Played sound for circle at 72262 ms
# Played sound for spinner at 72324 ms
# Played sound for spinner at 76324 ms
# Simulation finished!

# %%
import csv
import os


class DataExporter:
    def __init__(self, dataset_folder):
        os.makedirs(dataset_folder, exist_ok=True)
        self.beatmaps_file = os.path.join(dataset_folder, "beatmaps.csv")
        self.hit_objects_file = os.path.join(dataset_folder, "hit_objects.csv")
        self.timing_points_file = os.path.join(dataset_folder, "timing_points.csv")

        self.init_csv()

    def init_csv(self):
        for file, headers in [
            (
                self.beatmaps_file,
                [
                    "ID",
                    "Title",
                    "Artist",
                    "Creator",
                    "Version",
                    "HPDrainRate",
                    "CircleSize",
                    "OverallDifficulty",
                    "ApproachRate",
                    "SliderMultiplier",
                    "SliderTickRate",
                ],
            ),
            (
                self.hit_objects_file,
                ["ID", "Time", "Type", "X", "Y", "HitSound", "Extra"],
            ),
            (
                self.timing_points_file,
                [
                    "ID",
                    "offset",
                    "ms_per_beat",
                    "time_signature",
                    "meter",
                    "sample_set",
                    "sample_index",
                    "volume",
                    "effects",
                ],
            ),
        ]:
            if not os.path.exists(file):
                with open(file, "w", newline="", encoding="utf-8") as f:
                    writer = csv.writer(f)
                    writer.writerow(headers)

    def write_data(self, data, id):
        hit_objects = data["hit_objects"]
        timing_points = data["timing_points"]
        metadata = data["metadata"]
        difficulty = data["difficulty"]

        self.save_beatmap(id, metadata, difficulty)
        self.save_hit_objects(id, hit_objects)
        self.save_timing_points(id, timing_points)

    def save_beatmap(self, id, metadata, difficulty):
        with open(self.beatmaps_file, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(
                [
                    id,
                    metadata.get("Title", ""),
                    metadata.get("Artist", ""),
                    metadata.get("Creator", ""),
                    metadata.get("Version", ""),
                    difficulty.get("HPDrainRate", ""),
                    difficulty.get("CircleSize", ""),
                    difficulty.get("OverallDifficulty", ""),
                    difficulty.get("ApproachRate", ""),
                    difficulty.get("SliderMultiplier", ""),
                    difficulty.get("SliderTickRate", ""),
                ]
            )

    def save_hit_objects(self, id, hit_objects):
        with open(self.hit_objects_file, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            for obj in hit_objects:
                extra = obj.get("path", obj.get("end_time", ""))
                writer.writerow(
                    [
                        id,
                        obj["time"],
                        obj["type"],
                        obj["x"],
                        obj["y"],
                        obj["hit_sound"],
                        extra,
                    ]
                )

    def save_timing_points(self, id, timing_points):
        with open(self.timing_points_file, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            for tp in timing_points:
                writer.writerow(
                    [
                        id,
                        tp.get("offset"),
                        tp.get("ms_per_beat"),
                        tp.get("time_signature"),
                        tp.get("meter"),
                        tp.get("sample_set"),
                        tp.get("sample_index"),
                        tp.get("volume"),
                        tp.get("effects"),
                    ]
                )

# %%
database_path = "example/dataset"
data_exporter = DataExporter(database_path)

# %%
osu_files = [
    file for file in os.listdir(beatmapset_folder) if file.endswith(".osu")
]
beatmapsetId = beatmapset_folder.split("-")[1]

for index, osu_file in enumerate(osu_files):
    id = beatmapsetId + "-" + str(index)
    processor = BeatmapProcessor(beatmapset_folder, osu_file)
    data = processor.get_data()
    data_exporter.write_data(data, id)

# %%
import shutil

audio_files = [
    f
    for f in os.listdir(beatmapset_folder)
    if f.lower().endswith((".mp3", ".ogg"))
]
audio_folder = os.path.join(database_path, "audio", beatmapset_folder.split("-")[1])
os.makedirs(audio_folder, exist_ok=True)

if audio_files:
    first_audio = audio_files[0]
    shutil.copy2(
        os.path.join(beatmapset_folder, first_audio),
        os.path.join(audio_folder, first_audio)
    )

# %%
import pandas as pd

df = pd.read_csv("example/dataset/beatmaps.csv")
df
# Out:
#           ID                     Title      Artist    Creator  \
# 0  2269930-0  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 1  2269930-1  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 2  2269930-2  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 3  2269930-3  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 4  2269930-4  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 5  2269930-5  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 6  2269930-6  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 7  2269930-7  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
# 8  2269930-8  Favorite Liar (Cut Ver.)  The Wrecks  PikAqours
#
#                    Version  HPDrainRate  CircleSize  OverallDifficulty  \
# 0  Kuroame's Favorite Liar          5.5         3.8                9.6
# 1          Harumi's Normal          3.0         3.2                3.8
# 2            Amats' Insane          5.0         3.6                8.0
# 3             Kuki's Extra          5.0         3.8                9.2
# 4        Parad0xa's Expert          5.2         3.6                8.8
# 5             Fuxi's Extra          5.0         3.8                9.3
# 6         My Favorite Liar          5.0         3.8                9.5
# 7            Armada's Easy          2.0         2.0                2.0
# 8                     Hard          4.0         3.6                7.0
#
#    ApproachRate  SliderMultiplier  SliderTickRate
# 0           9.7              1.80             1.0
# 1           5.8              0.90             1.0
# 2           9.0              1.55             1.0
# 3           9.4              1.80             1.0
# 4           9.2              1.60             0.5
# 5           9.4              1.82             1.0
# 6           9.6              1.81             1.0
# 7           4.0              0.90             1.0
# 8           8.0              1.31             1.0
